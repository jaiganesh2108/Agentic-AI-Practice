# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
with open("blood_work.txt","r") as f:
    blood_report = f.read()

print(blood_report[:223])
# Out:
# Patient: Rajesh Sharma, Age 48, Male
# Date: May 7, 2026
#
# COMPLETE BLOOD COUNT (CBC)
# --------------------------
# Hemoglobin:        15.1 g/dL        (Normal: 13.5â€“17.5)
# Hematocrit:        44%              (Normal: 41â€“53%)

# %%
extraction_prompt = f"""
You ar a medical data extraction analysis.

From the blood report below, extract All test values and classify each of them with HIGH, LOW, or NORMAL based on the reference ranges
provided in the report

Format Your response as:
- Test Name: value | Status: HIGH/LOW/NORMAL | Reference: range

Blood Report:
{blood_report}
"""

extraction_response = llm.invoke(extraction_prompt)
extracted_values = extraction_response.text

print("=== STAGE 1 EXTRACTED VALUES ===")
print(extracted_values)
# Out:
# === STAGE 1 EXTRACTED VALUES ===
# Here is the extraction and classification of the blood test values:
#
# - Hemoglobin: 15.1 g/dL | Status: NORMAL | Reference: 13.5–17.5
# - Hematocrit: 44% | Status: NORMAL | Reference: 41–53%
# - WBC: 6.8 x10^3/uL | Status: NORMAL | Reference: 4.5–11.0
# - Platelets: 220 x10^3/uL | Status: NORMAL | Reference: 150–400
# - Total Cholesterol: 238 mg/dL | Status: HIGH | Reference: <200
# - LDL Cholesterol: 162 mg/dL | Status: HIGH | Reference: <100
# - HDL Cholesterol: 36 mg/dL | Status: LOW | Reference: >40
# - Triglycerides: 188 mg/dL | Status: HIGH | Reference: <150
# - Glucose (Fasting): 92 mg/dL | Status: NORMAL | Reference: 70–99
# - HbA1c: 5.3% | Status: NORMAL | Reference: <5.7%
# - Creatinine: 1.0 mg/dL | Status: NORMAL | Reference: 0.7–1.3
# - eGFR: 82 mL/min | Status: NORMAL | Reference: >60
# - ALT: 28 U/L | Status: NORMAL | Reference: 7–40
# - AST: 25 U/L | Status: NORMAL | Reference: 10–40
# - Bilirubin Total: 0.8 mg/dL | Status: NORMAL | Reference: 0.2–1.2

# %%
diet_prompt = f"""
You are a clinical nutritionist specializing in indian dietary habits.
Based on the blood work analysis below, write:
1. A short health summary in 3 lines explaining the patient's condition in simple language
2. A short, practical indian diet plan having only two sections (1) Foods to avoid (2) Foods to eat more of.
    Do not include any other sections in diet plan.

BLOOD WORK ANALYSIS:
{extracted_values}
"""
diet_response = llm.invoke(diet_prompt)
print("=== STAGE 2: HEALTH SUMMARY & DIET PLAN ===")
print(diet_response.text)
# Out:
# === STAGE 2: HEALTH SUMMARY & DIET PLAN ===
# Here is your health summary and a practical Indian diet plan:
#
# ---
#
# **1. Health Summary:**
#
# Your blood tests show elevated levels of "bad" cholesterol (LDL) and triglycerides, coupled with lower "good" cholesterol (HDL). This pattern suggests an increased risk for heart health concerns. Fortunately, your blood sugar and other organ functions are currently within healthy limits.
#
# ---
#
# **2. Indian Diet Plan:**
#
# **Foods to Avoid:**
#
# *   **Deep-fried snacks:** Samosas, pakoras, puri, vada, and other fried items.
# *   **Excessive Ghee & Butter:** Limit their use in cooking and as toppings.
# *   **Full-fat dairy products:** Malai, full-fat paneer, and full-cream milk.
# *   **Processed foods & bakery items:** Biscuits, cakes, pastries, and items made with refined flour (maida) or unhealthy fats.
# *   **Sweets & sugary drinks:** Mithai, jalebi, sugary beverages, and excessive jaggery.
# *   **Red meat & organ meats:** Limit mutton and organ meats; reduce highly processed meats.
#
# **Foods to Eat More Of:**
#
# *   **Whole grains:** Atta for rotis/chapatis, brown rice, oats, bajra, jowar, ragi.
# *   **Plenty of vegetables & fruits:** Focus on leafy greens (palak, methi), gourds, and a variety of seasonal fruits daily.
# *   **Lentils & legumes:** All types of dal (moong, masoor, arhar), chana, rajma, and sprouts.
# *   **Healthy fats:** Small handful of nuts (almonds, walnuts), seeds (flax seeds, chia seeds), and use moderate amounts of heart-healthy oils like mustard oil or rice bran oil for cooking.
# *   **Lean protein:** Fish (especially fatty fish), skinless chicken, low-fat paneer, tofu, and legumes.
# *   **Low-fat dairy:** Skimmed milk, low-fat curd, and buttermilk (chaas).
