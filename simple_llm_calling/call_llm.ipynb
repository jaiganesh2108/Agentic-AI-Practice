# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(model="gemma-4-31b-it")
response = llm.invoke("How many moons does jupyter have?")
print(response.text)
# Out:
# As of the most recent data from NASA, **Jupiter has 95 recognized moons**.
#
# The number of known moons often changes as astronomers discover new, smaller ones. While there are dozens of small moons, the most famous are the four **Galilean moons**, which are much larger: **Io, Europa, Ganymede, and Callisto**.
